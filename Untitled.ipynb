# %%
import cv2
import numpy as np
import tensorflow as tf

# %%
import os
file = os.path.join(os.getcwd()+'/annotation_file.json')

# %%
import json
with tf.gfile.GFile(file) as f:
    obj = json.load(f)

# %%
bbox = obj[0]
label = bbox['Label']
label_2 = label['objects']
#box1 = label_2[0]

# %%
label
# Out:
# {'objects': [{'featureId': 'ck8an8f5g3gbe0zad6hmb8uly',
#    'schemaId': 'ck8an7lfa2b3i08307j65tdgj',
#    'title': 'person',
#    'value': 'person',
#    'color': '#FF0000',
#    'bbox': {'top': 162, 'left': 188, 'height': 190, 'width': 54},
#    'instanceURI': 'https://api.labelbox.com/masks/feature/ck8an8f5g3gbe0zad6hmb8uly?token=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VySWQiOiJjazhhbHd6MmdxcGJ2MDgzMjBpcTN5ZDFrIiwib3JnYW5pemF0aW9uSWQiOiJjazhhbHd6MjA5c2ZlMDgyNmIyOXRvMXFoIiwiaWF0IjoxNTg1MzQyMDQ4LCJleHAiOjE1ODc5MzQwNDh9.Da7ANiQ20-C8cdI9KG4rw_LyThjeHHfxDhpEYGW58_8'},
#   {'featureId': 'ck8an8pea3gca0zadhjs159ua',
#    'schemaId': 'ck8an7lfa2b3i08307j65tdgj',
#    'title': 'person',
#    'value': 'person',
#    'color': '#FF0000',
#    'bbox': {'top': 121, 'left': 130, 'height': 96, 'width': 34},
# ...

# %%
len(label_2)
# Out:
# 7

# %%
labelstext =["person", "bicycle", "car", "motorbike", "aeroplane", "bus", "train", "truck", "boat", "traffic light", "fire hydrant", "stop sign", "parking meter", "bench", "bird", "cat", "dog", "horse", "sheep", "cow", "elephant", "bear", "zebra", "giraffe", "backpack", "umbrella", "handbag", "tie", "suitcase", "frisbee", "skis", "snowboard", "sports ball", "kite", "baseball bat", "baseball glove", "skateboard", "surfboard", "tennis racket", "bottle", "wine glass", "cup", "fork", "knife", "spoon", "bowl", "banana", "apple", "sandwich", "orange", "broccoli", "carrot", "hot dog", "pizza", "donut", "cake", "chair", "sofa", "pottedplant", "bed", "diningtable", "toilet", "tvmonitor", "laptop", "mouse", "remote", "keyboard", "cell phone", "microwave", "oven", "toaster", "sink", "refrigerator", "book", "clock", "vase", "scissors", "teddy bear", "hair drier", "toothbrush"]
def creat_bbox(filename):
    with tf.gfile.GFile(filename) as f:
        obj = json.load(f)
    count = 0
    bbox = obj[0]
    label = bbox['Label']
    label_2 = label['objects']
    for j in range(len(label_2)):
        bb = label_2[j]
        int_label = 0
        for a,x in enumerate(labelstext):
            if x == bb['value']:
                int_label = a
        y1 = bb['bbox']['top'] #y1
        x1 = bb['bbox']['left']#x1
        y2 = bb['bbox']['height']+ bb['bbox']['top'] #y2
        x2 = bb['bbox']['width']+ bb['bbox']['left']#x2
        bbox = np.array([[y1,x1,y2,x2,int_label]])
        if count == 0:
            coord = bbox
            count +=1
        else:
            coord = np.concatenate((coord,bbox),axis = 0)
            count += 1
    return coord

# %%
bbox = creat_bbox(file)

# %%
bbox
# Out:
# array([[162, 188, 352, 242,   0],
#        [121, 130, 217, 164,   0],
#        [151, 280, 284, 321,   0],
#        [126, 313, 216, 343,   0],
#        [179, 333, 329, 414,   0],
#        [135, 507, 249, 567,   0],
#        [121, 531, 152, 552,   0]])

# %%
def draw_box_bb(image,boxes):
    if len(boxes)==0:
        return image
    else:
        for i in range(len(boxes)):
            x1 = boxes[i,1:2]
            y1 = boxes[i,0:1]
            x2 = boxes[i,3:4]
            y2 = boxes[i,2:3]
            cv2.rectangle(image,(x1,y1),(x2,y2),(255,0,0),2)
    return image

# %%
data_image_dir = os.path.join(os.getcwd()+'/coco_test1.jpg')
image = cv2.imread(data_image_dir)
image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
image_input = np.array(image,dtype = np.float32)/255
height = image_input.shape[0]
width = image_input.shape[1]

# %%
image_copy = np.array((height,width,3))
image_copy = draw_box_bb(image_input,bbox)

# %%
from matplotlib import pyplot as plt
plt.imshow(image_copy)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
bbox
# Out:
# array([[162, 188, 352, 242,   0],
#        [121, 130, 217, 164,   0],
#        [151, 280, 284, 321,   0],
#        [126, 313, 216, 343,   0],
#        [179, 333, 329, 414,   0],
#        [135, 507, 249, 567,   0],
#        [121, 531, 152, 552,   0]])

# %%
bbox.shape
# Out:
# (7, 5)

# %%
def iou(bb1,bb2):
    x_left = max(bb1[:,1:2], bb2[:,1:2])
    y_top = max(bb1[:,0:1], bb2[:,0:1])
    x_right = min(bb1[:,3:4], bb2[:,3:4])
    y_bottom = min(bb1[:,2:3], bb2[:,2:3])
    if x_right < x_left or y_bottom < y_top:
        return 0.0
    intersection_area = np.multiply((x_right - x_left),(y_bottom - y_top))
    bb1_area = np.multiply((bb1[:,3:4] - bb1[:,1:2]),(bb1[:,2:3] - bb1[:,0:1]))
    bb2_area = np.multiply((bb2[:,3:4] - bb2[:,1:2]),(bb2[:,2:3] - bb2[:,0:1]))
    S = float(bb1_area + bb2_area - intersection_area)
    iou = np.divide(intersection_area,S)
    assert iou >= 0.0
    assert iou <= 1.0
    return iou

# %%
def cal_recall(gt_bboxes, bboxes, iou_thres=0.5):
    p = 0
    tp = 0
    for idx, (gt, bbox) in enumerate(zip(gt_bboxes, bboxes)):
        gt = gt[np.nonzero(np.any(gt > 0, axis=1))]
        bbox = bbox[np.nonzero(np.any(bbox > 0, axis=1))]
        p += len(gt)
        if bbox.size == 0:
            continue
        iou = iou(gt, bbox)
        predicted_class = np.argmax(bbox[...,5:], axis=-1)
        for g, area in zip(gt, iou):
            gt_c = np.argmax(g[5:])
            idx = np.argmax(area)
            if np.max(area) > iou_thres and predicted_class[idx] == gt_c:
                tp += 1
    return tp / p
# Out:
# array([[162, 188, 352, 242,   0],
#        [121, 130, 217, 164,   0],
#        [151, 280, 284, 321,   0],
#        [126, 313, 216, 343,   0],
#        [179, 333, 329, 414,   0],
#        [135, 507, 249, 567,   0],
#        [121, 531, 152, 552,   0]])

# %%
gt_bboxes= np.array([[168, 182, 352, 242,   0],
       [121, 130, 217, 164,   0],
       [151, 280, 284, 321,   0],
       [126, 313, 216, 343,   0],
       [179, 333, 329, 414,   0],
       [135, 507, 249, 567,   0],
       [121, 531, 152, 552,   0],
       [150, 336, 359, 434,   0]])

# %%
bbb = np.array([[150, 336, 359, 434,   0]])
for idx, (gt, bbox) in enumerate(zip(bbb, bbox)):
    print(gt)
    print(bbox)
    print(idx)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-8c7dd8d24b5a> in <module>
#       1 bbb = np.array([[150, 336, 359, 434,   0]])
# ----> 2 for idx, (gt, bbox) in enumerate(zip(bbb, bbox)):
#       3     print(gt)
#       4     print(bbox)
#       5     print(idx)
#
# TypeError: zip argument #2 must support iteration
